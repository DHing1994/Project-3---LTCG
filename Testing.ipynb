# %%
import requests
import json
from config import api_key
from pprint import pprint

# %%
url = "https://play.limitlesstcg.com/api"
api_key = "?key="+ api_key

# %%
response = requests.get(url+"/tournaments"+api_key)
data=response.json()
pprint(response.json())
# Out:
# [{'date': '2023-04-27T00:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '641b2e5e25171155a799c84e',
#   'name': 'Full Heal S2 #4 (50 Codes, FREE ENTRY!)',
#   'players': 51},
#  {'date': '2023-04-27T00:00:00.000Z',
#   'format': None,
#   'game': 'PTCG',
#   'id': '6446f36d0ed4a405d8bd9788',
#   'name': 'Dead Draw Final 6',
#   'players': 6},
#  {'date': '2023-04-26T23:25:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '6446f2d90ed4a405d8bd9784',
#   'name': 'FTG Wednesday Weekly 77',
#   'players': 21},
#  {'date': '2023-04-26T23:05:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '63cdf252f61c172bc031fd8d',
#   'name': 'Gargalon Gauntlet Standard #6 | 500 S&V CODES!',
#   'players': 170},
#  {'date': '2023-04-26T23:00:00.000Z',
#   'format': '23S3',
#   'game': 'VGC',
#   'id': '6449777e0ed4a405d8bda708',
#   'name': 'Wooper Wednesdays #14',
#   'players': 21},
#  {'date': '2023-04-26T23:00:00.000Z',
#   'format': '23S3',
#   'game': 'VGC',
#   'id': '6447498a0ed4a405d8bd9b11',
#   'name': 'Tri-Attack Freeze battles #13',
#   'players': 37},
#  {'date': '2023-04-26T23:00:00.000Z',
#   'format': None,
#   'game': 'DCG',
#   'id': '6445546f0ed4a405d8bd8f9b',
#   'name': 'Digimon MGW Circuit Tournament Season 3 - #16',
#   'players': 40},
#  {'date': '2023-04-26T19:00:00.000Z',
#   'format': 'GLC',
#   'game': 'PTCG',
#   'id': '644150610ed4a405d8bd7d88',
#   'name': 'CBW GLC Webcam #4',
#   'players': 11},
#  {'date': '2023-04-26T18:25:00.000Z',
#   'format': 'EXPANDED',
#   'game': 'PTCG',
#   'id': '64339e390ed4a405d8bd3aa8',
#   'name': 'Webcam Series 3',
#   'players': 14},
#  {'date': '2023-04-26T17:30:00.000Z',
#   'format': None,
#   'game': 'other',
#   'id': '6447bb050ed4a405d8bd9b90',
#   'name': 'Semanal Online Homelands - One Piece Card Game',
#   'players': 13},
#  {'date': '2023-04-26T17:00:00.000Z',
#   'format': '23S3',
#   'game': 'VGC',
#   'id': '64469e440ed4a405d8bd9580',
#   'name': 'The Sprout Tower Weekly #12',
#   'players': 24},
#  {'date': '2023-04-26T17:00:00.000Z',
#   'format': None,
#   'game': 'DCG',
#   'id': '6447ba5e0ed4a405d8bd9b8d',
#   'name': 'Semanal Online Homelands - Digimon',
#   'players': 6},
#  {'date': '2023-04-26T13:30:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '644029760ed4a405d8bd7934',
#   'name': 'MorningTCG Weekly #3 |PTCGL|50 Codes|',
#   'players': 59},
#  {'date': '2023-04-26T12:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '644019c60ed4a405d8bd78d6',
#   'name': 'The Discard Pile Weekly Standard #11 (Standard)',
#   'players': 37},
#  {'date': '2023-04-26T02:00:00.000Z',
#   'format': None,
#   'game': 'DCG',
#   'id': '643d6c960ed4a405d8bd666b',
#   'name': 'Emerald Dragon Cup 2',
#   'players': 7},
#  {'date': '2023-04-26T00:30:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '6447f18c0ed4a405d8bd9c3f',
#   'name': 'Hoarders Casual #31',
#   'players': 123},
#  {'date': '2023-04-25T23:30:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '64485e240ed4a405d8bda17f',
#   'name': 'late night replacement ',
#   'players': 6},
#  {'date': '2023-04-25T23:30:00.000Z',
#   'format': '23S3',
#   'game': 'VGC',
#   'id': '643fe7090ed4a405d8bd7787',
#   'name': 'PokePal Smackdown #3',
#   'players': 22},
#  {'date': '2023-04-25T23:00:00.000Z',
#   'format': None,
#   'game': 'DCG',
#   'id': '643967fc0ed4a405d8bd554c',
#   'name': 'DMV Drakes Bi-weekly Digimon Bancho Beatdown 04/25',
#   'players': 17},
#  {'date': '2023-04-25T23:00:00.000Z',
#   'format': '23S3',
#   'game': 'VGC',
#   'id': '63c7727ef61c172bc031d269',
#   'name': "Tommy's Tuesday Practice Tour",
#   'players': 21},
#  {'date': '2023-04-25T23:00:00.000Z',
#   'format': None,
#   'game': 'DCG',
#   'id': '6446adac0ed4a405d8bd95c9',
#   'name': "The Eagle's Nest Circuit Series Two #3 (BT12)",
#   'players': 4},
#  {'date': '2023-04-25T17:15:00.000Z',
#   'format': '23S3',
#   'game': 'VGC',
#   'id': '64235cc325171155a799e9c7',
#   'name': 'MausTour Weekly 2.4',
#   'players': 32},
#  {'date': '2023-04-25T16:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '640673af24ea2b561a987906',
#   'name': 'Late Night #93 on PTCG Live | Road to Japan',
#   'players': 236},
#  {'date': '2023-04-25T15:00:00.000Z',
#   'format': None,
#   'game': 'other',
#   'id': '64464f6a0ed4a405d8bd9412',
#   'name': 'One Piece Tuesdays',
#   'players': 14},
#  {'date': '2023-04-25T00:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '64449db30ed4a405d8bd8dbd',
#   'name': 'Free entry ║ Deck Out Mondays ║ 200 codes',
#   'players': 109},
#  {'date': '2023-04-24T23:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '6446490f0ed4a405d8bd9404',
#   'name': 'Poke Liga Online 24/04',
#   'players': 4},
#  {'date': '2023-04-24T22:05:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '643f2ed90ed4a405d8bd725d',
#   'name': "Sunny's Weekly #100 Celebration of 100 Weeks!",
#   'players': 110},
#  {'date': '2023-04-24T22:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '644646d60ed4a405d8bd93ff',
#   'name': 'FalaMeowth! "5/0 Hero" #08',
#   'players': 32},
#  {'date': '2023-04-24T18:30:00.000Z',
#   'format': None,
#   'game': 'DCG',
#   'id': '644578f00ed4a405d8bd9114',
#   'name': "Gordo's Games Monday League BT11",
#   'players': 12},
#  {'date': '2023-04-24T18:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '6445562e0ed4a405d8bd8fbb',
#   'name': 'Standard Pumpka Weekly ',
#   'players': 64},
#  {'date': '2023-04-24T11:30:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '643df8b10ed4a405d8bd69da',
#   'name': 'Monday Morning Matches #12',
#   'players': 40},
#  {'date': '2023-04-23T23:30:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '644425f50ed4a405d8bd8a90',
#   'name': 'underground special',
#   'players': 29},
#  {'date': '2023-04-23T21:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '643c45be0ed4a405d8bd636c',
#   'name': 'Peladão da Baixada #87 @ PTCG LIVE',
#   'players': 40},
#  {'date': '2023-04-23T20:05:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '642b8ffeaf9fbd0613b1db7d',
#   'name': 'Mick weekly 1',
#   'players': 7},
#  {'date': '2023-04-23T19:00:00.000Z',
#   'format': 'CUSTOM',
#   'game': 'VGC',
#   'id': '64270d0625171155a799fa5b',
#   'name': 'Tournoi Médiocremon',
#   'players': 6},
#  {'date': '2023-04-23T17:30:00.000Z',
#   'format': '23S3',
#   'game': 'VGC',
#   'id': '643c4c510ed4a405d8bd63a4',
#   'name': 'COPA PALAFIN #1',
#   'players': 18},
#  {'date': '2023-04-23T17:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '642c85f7af9fbd0613b1e27a',
#   'name': 'Trainer Academy|SUNDAY@SIX|TOP8|PRIZES|',
#   'players': 58},
#  {'date': '2023-04-23T16:00:00.000Z',
#   'format': '23S3',
#   'game': 'VGC',
#   'id': '64092afd8089a75fd54c6510',
#   'name': 'SpearPillar Showdown #7',
#   'players': 12},
#  {'date': '2023-04-23T15:00:00.000Z',
#   'format': '23S3',
#   'game': 'VGC',
#   'id': '64382feb0ed4a405d8bd5010',
#   'name': 'VGC 2023; International challenge!',
#   'players': 47},
#  {'date': '2023-04-23T14:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '643e74e40ed4a405d8bd6a62',
#   'name': 'Pokemon tcg suomi PTCGl tournament! 30 CODES!',
#   'players': 75},
#  {'date': '2023-04-23T00:30:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '644446f30ed4a405d8bd8b8c',
#   'name': 'Hoarders Circuit Series #22',
#   'players': 55},
#  {'date': '2023-04-22T23:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '6442cbb90ed4a405d8bd82ff',
#   'name': 'Poke Liga Online 22/04',
#   'players': 4},
#  {'date': '2023-04-22T22:45:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '64370f350ed4a405d8bd4ab2',
#   'name': 'Lax-Station New Rotation Webcam #2',
#   'players': 20},
#  {'date': '2023-04-22T20:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '643b467c0ed4a405d8bd5f96',
#   'name': 'Pokevice League - Pokémon TCG #3',
#   'players': 7},
#  {'date': '2023-04-22T19:30:00.000Z',
#   'format': '23S3',
#   'game': 'VGC',
#   'id': '6442e3c50ed4a405d8bd83c2',
#   'name': 'LPM Online - Scarlet & Violet #002',
#   'players': 8},
#  {'date': '2023-04-22T19:00:00.000Z',
#   'format': None,
#   'game': 'DCG',
#   'id': '643bb2fb0ed4a405d8bd6145',
#   'name': 'TORNEO #28 DIGIMON ROSARIO 22/4',
#   'players': 8},
#  {'date': '2023-04-22T18:00:00.000Z',
#   'format': '23S3',
#   'game': 'VGC',
#   'id': '640bb2e421433a05cd052c72',
#   'name': 'The Umbreon Cup (VGC)',
#   'players': 40},
#  {'date': '2023-04-22T16:05:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '64432fab0ed4a405d8bd85b2',
#   'name': "The Vault's SV 1K",
#   'players': 22},
#  {'date': '2023-04-22T16:00:00.000Z',
#   'format': None,
#   'game': 'DCG',
#   'id': '64428dce0ed4a405d8bd8205',
#   'name': 'PHOENIX REBORN DIGIMON 250 11°',
#   'players': 47},
#  {'date': '2023-04-22T15:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '643192280ed4a405d8bd2941',
#   'name': 'PKMN Live Scarlet&Violet (Free Entry)',
#   'players': 65}]

# %%
#limiting response to TCG only
# response = requests.get(url+"/tournaments/"+api_key+"&game=PTCG&limit=200")
response = requests.get(url+"/tournaments/"+api_key+"&game=PTCG&limit=200")
data=response.json()
pprint(response.json())
# Out:
# [{'date': '2023-04-27T00:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '641b2e5e25171155a799c84e',
#   'name': 'Full Heal S2 #4 (50 Codes, FREE ENTRY!)',
#   'players': 51},
#  {'date': '2023-04-27T00:00:00.000Z',
#   'format': None,
#   'game': 'PTCG',
#   'id': '6446f36d0ed4a405d8bd9788',
#   'name': 'Dead Draw Final 6',
#   'players': 6},
#  {'date': '2023-04-26T23:25:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '6446f2d90ed4a405d8bd9784',
#   'name': 'FTG Wednesday Weekly 77',
#   'players': 21},
#  {'date': '2023-04-26T23:05:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '63cdf252f61c172bc031fd8d',
#   'name': 'Gargalon Gauntlet Standard #6 | 500 S&V CODES!',
#   'players': 170},
#  {'date': '2023-04-26T19:00:00.000Z',
#   'format': 'GLC',
#   'game': 'PTCG',
#   'id': '644150610ed4a405d8bd7d88',
#   'name': 'CBW GLC Webcam #4',
#   'players': 11},
#  {'date': '2023-04-26T18:25:00.000Z',
#   'format': 'EXPANDED',
#   'game': 'PTCG',
#   'id': '64339e390ed4a405d8bd3aa8',
#   'name': 'Webcam Series 3',
#   'players': 14},
#  {'date': '2023-04-26T13:30:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '644029760ed4a405d8bd7934',
#   'name': 'MorningTCG Weekly #3 |PTCGL|50 Codes|',
#   'players': 59},
#  {'date': '2023-04-26T12:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '644019c60ed4a405d8bd78d6',
#   'name': 'The Discard Pile Weekly Standard #11 (Standard)',
#   'players': 37},
#  {'date': '2023-04-26T00:30:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '6447f18c0ed4a405d8bd9c3f',
#   'name': 'Hoarders Casual #31',
#   'players': 123},
#  {'date': '2023-04-25T23:30:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '64485e240ed4a405d8bda17f',
#   'name': 'late night replacement ',
#   'players': 6},
#  {'date': '2023-04-25T16:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '640673af24ea2b561a987906',
#   'name': 'Late Night #93 on PTCG Live | Road to Japan',
#   'players': 236},
#  {'date': '2023-04-25T00:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '64449db30ed4a405d8bd8dbd',
#   'name': 'Free entry ║ Deck Out Mondays ║ 200 codes',
#   'players': 109},
#  {'date': '2023-04-24T23:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '6446490f0ed4a405d8bd9404',
#   'name': 'Poke Liga Online 24/04',
#   'players': 4},
#  {'date': '2023-04-24T22:05:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '643f2ed90ed4a405d8bd725d',
#   'name': "Sunny's Weekly #100 Celebration of 100 Weeks!",
#   'players': 110},
#  {'date': '2023-04-24T22:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '644646d60ed4a405d8bd93ff',
#   'name': 'FalaMeowth! "5/0 Hero" #08',
#   'players': 32},
#  {'date': '2023-04-24T18:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '6445562e0ed4a405d8bd8fbb',
#   'name': 'Standard Pumpka Weekly ',
#   'players': 64},
#  {'date': '2023-04-24T11:30:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '643df8b10ed4a405d8bd69da',
#   'name': 'Monday Morning Matches #12',
#   'players': 40},
#  {'date': '2023-04-23T23:30:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '644425f50ed4a405d8bd8a90',
#   'name': 'underground special',
#   'players': 29},
#  {'date': '2023-04-23T21:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '643c45be0ed4a405d8bd636c',
#   'name': 'Peladão da Baixada #87 @ PTCG LIVE',
#   'players': 40},
#  {'date': '2023-04-23T20:05:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '642b8ffeaf9fbd0613b1db7d',
#   'name': 'Mick weekly 1',
#   'players': 7},
#  {'date': '2023-04-23T17:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '642c85f7af9fbd0613b1e27a',
#   'name': 'Trainer Academy|SUNDAY@SIX|TOP8|PRIZES|',
#   'players': 58},
#  {'date': '2023-04-23T14:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '643e74e40ed4a405d8bd6a62',
#   'name': 'Pokemon tcg suomi PTCGl tournament! 30 CODES!',
#   'players': 75},
#  {'date': '2023-04-23T00:30:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '644446f30ed4a405d8bd8b8c',
#   'name': 'Hoarders Circuit Series #22',
#   'players': 55},
#  {'date': '2023-04-22T23:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '6442cbb90ed4a405d8bd82ff',
#   'name': 'Poke Liga Online 22/04',
#   'players': 4},
#  {'date': '2023-04-22T22:45:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '64370f350ed4a405d8bd4ab2',
#   'name': 'Lax-Station New Rotation Webcam #2',
#   'players': 20},
#  {'date': '2023-04-22T20:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '643b467c0ed4a405d8bd5f96',
#   'name': 'Pokevice League - Pokémon TCG #3',
#   'players': 7},
#  {'date': '2023-04-22T16:05:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '64432fab0ed4a405d8bd85b2',
#   'name': "The Vault's SV 1K",
#   'players': 22},
#  {'date': '2023-04-22T15:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '643192280ed4a405d8bd2941',
#   'name': 'PKMN Live Scarlet&Violet (Free Entry)',
#   'players': 65},
#  {'date': '2023-04-22T13:30:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '6420351925171155a799ddca',
#   'name': '1k da NewStation 22/04',
#   'players': 25},
#  {'date': '2023-04-22T13:00:00.000Z',
#   'format': 'CUSTOM',
#   'game': 'PTCG',
#   'id': '6426e68f25171155a799f9e9',
#   'name': ' JIBX #15 - Eternal Format (Base Set Onward)',
#   'players': 6},
#  {'date': '2023-04-22T02:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '643992070ed4a405d8bd5598',
#   'name': 'TOURNAMENT OF DOOM! Who Wins?',
#   'players': 79},
#  {'date': '2023-04-22T00:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '6442ab9b0ed4a405d8bd8248',
#   'name': 'Hoarders Circuit Series #21',
#   'players': 71},
#  {'date': '2023-04-21T20:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '6440a7840ed4a405d8bd7cd4',
#   'name': 'Gobal Locals ',
#   'players': 5},
#  {'date': '2023-04-21T19:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '6441996d0ed4a405d8bd7e26',
#   'name': 'Standard Pumpka Weekly ',
#   'players': 47},
#  {'date': '2023-04-21T17:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '63b1c24dfa281305be50dfb7',
#   'name': 'LuckySquad Grinder #8 | Sponsored by Pokemons.dk',
#   'players': 75},
#  {'date': '2023-04-21T11:30:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '6439cf660ed4a405d8bd565d',
#   'name': 'The Discard Pile Weekly #10 (SINGLE PRIZE)',
#   'players': 18},
#  {'date': '2023-04-21T00:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '6441c0b40ed4a405d8bd7eed',
#   'name': 'Hoarders Casual #30',
#   'players': 18},
#  {'date': '2023-04-20T23:00:00.000Z',
#   'format': 'RMEP',
#   'game': 'PTCG',
#   'id': '64374df70ed4a405d8bd4d30',
#   'name': 'Webcam Wars #5',
#   'players': 9},
#  {'date': '2023-04-20T23:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '6441a5030ed4a405d8bd7e4e',
#   'name': 'PS LEAGUE ETAPA #65',
#   'players': 14},
#  {'date': '2023-04-20T23:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '63fe75662fb42a11441fc033',
#   'name': 'Free Entry | $130 Store Credit | Qualifier #8',
#   'players': 135},
#  {'date': '2023-04-20T19:10:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '643d39e30ed4a405d8bd6589',
#   'name': 'Rule Zero’s SVI - League #2',
#   'players': 29},
#  {'date': '2023-04-20T18:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '64413e640ed4a405d8bd7d70',
#   'name': 'Hidden Gem Weeknight League',
#   'players': 6},
#  {'date': '2023-04-20T00:00:00.000Z',
#   'format': 'GLC',
#   'game': 'PTCG',
#   'id': '6437f3ad0ed4a405d8bd4f90',
#   'name': 'CBW GLC Webcam #3',
#   'players': 13},
#  {'date': '2023-04-20T00:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '641b2e0d25171155a799c84c',
#   'name': 'Full Heal S2 #3 (50 Codes, FREE ENTRY!)',
#   'players': 104},
#  {'date': '2023-04-19T23:30:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '643dc17e0ed4a405d8bd686c',
#   'name': 'FTG Wednesday Weekly 76',
#   'players': 30},
#  {'date': '2023-04-19T23:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '6438e1070ed4a405d8bd54c4',
#   'name': 'Poke Liga Online 19/04',
#   'players': 7},
#  {'date': '2023-04-19T22:59:00.000Z',
#   'format': None,
#   'game': 'PTCG',
#   'id': '643dc1ef0ed4a405d8bd686e',
#   'name': 'Dead Draw Final 8 ',
#   'players': 8},
#  {'date': '2023-04-19T13:30:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '6436c85b0ed4a405d8bd497a',
#   'name': 'MorningTCG Weekly #2 |PTCGL| 72 SV Codes|',
#   'players': 47},
#  {'date': '2023-04-19T12:30:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '6438d3db0ed4a405d8bd54aa',
#   'name': 'The Discard Pile Weekly Standard #9 (Standard)',
#   'players': 42},
#  {'date': '2023-04-19T00:30:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '643eec160ed4a405d8bd6e56',
#   'name': 'Hoarders Casual #29',
#   'players': 43},
#  {'date': '2023-04-18T23:38:00.000Z',
#   'format': 'CUSTOM',
#   'game': 'PTCG',
#   'id': '643eaa010ed4a405d8bd6aec',
#   'name': "Liga Jornada na Player's Stop #14",
#   'players': 4},
#  {'date': '2023-04-18T23:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '6406731a24ea2b561a987903',
#   'name': 'Late Night #92 on PTCG Live | Road to Japan',
#   'players': 335},
#  {'date': '2023-04-18T22:30:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '643876470ed4a405d8bd50a4',
#   'name': 'Torneio Semanal Pokedeck com créditos na loja',
#   'players': 18},
#  {'date': '2023-04-18T17:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '642c6cbdaf9fbd0613b1e121',
#   'name': 'Trainer Academy|POST-EUIC|TOP-8|PRIZE|SV CODES|',
#   'players': 22},
#  {'date': '2023-04-18T16:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '640672a424ea2b561a9878f0',
#   'name': 'Late Night #91 on PTCG Live | Road to Japan',
#   'players': 208},
#  {'date': '2023-04-18T00:00:00.000Z',
#   'format': 'RMEP',
#   'game': 'PTCG',
#   'id': '643dbe280ed4a405d8bd6848',
#   'name': 'underground special',
#   'players': 26},
#  {'date': '2023-04-17T22:05:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '6434c4830ed4a405d8bd4171',
#   'name': "Sunny's Weekly #99",
#   'players': 64},
#  {'date': '2023-04-17T22:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '643cb14e0ed4a405d8bd64f2',
#   'name': 'FalaMeowth! "5/0 Hero" #07',
#   'players': 28},
#  {'date': '2023-04-17T18:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '643d12440ed4a405d8bd6535',
#   'name': 'Standard Pumpka Weekly ',
#   'players': 64},
#  {'date': '2023-04-17T14:00:00.000Z',
#   'format': 'LEGACY',
#   'game': 'PTCG',
#   'id': '6437eb340ed4a405d8bd4f88',
#   'name': 'Path to the Geek Legacy #6',
#   'players': 8},
#  {'date': '2023-04-17T11:30:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '64349aa00ed4a405d8bd4005',
#   'name': 'Monday Morning Matches #11',
#   'players': 27},
#  {'date': '2023-04-16T21:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '63bec831fa281305be511f13',
#   'name': 'Peladão da Baixada #86 @ PTCG LIVE (SV1 LEGAL)',
#   'players': 42},
#  {'date': '2023-04-16T16:10:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '640f339621433a05cd053ef5',
#   'name': "🏆Moujii's Dojo🏆 Final Bout Open",
#   'players': 64},
#  {'date': '2023-04-16T16:10:00.000Z',
#   'format': 'EXPANDED',
#   'game': 'PTCG',
#   'id': '64339e150ed4a405d8bd3aa7',
#   'name': 'Webcam Series 2',
#   'players': 16},
#  {'date': '2023-04-16T08:54:00.000Z',
#   'format': 'EX',
#   'game': 'PTCG',
#   'id': '643bb3480ed4a405d8bd6146',
#   'name': 'EUIC ex series round #3',
#   'players': 9},
#  {'date': '2023-04-16T00:30:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '6434bad60ed4a405d8bd413e',
#   'name': 'Hoarders Circuit Series #20 Post Rotation',
#   'players': 110},
#  {'date': '2023-04-15T18:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '643984aa0ed4a405d8bd557a',
#   'name': '2023 GU Saturday Tournament #14',
#   'players': 13},
#  {'date': '2023-04-15T16:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '642b582faf9fbd0613b1d922',
#   'name': 'Card Cavern Trading Cards 2023 🏆 Standard #1',
#   'players': 107},
#  {'date': '2023-04-15T14:30:00.000Z',
#   'format': 'EX',
#   'game': 'PTCG',
#   'id': '643a9ad20ed4a405d8bd5a1a',
#   'name': 'EUIC ex series Tournament #2',
#   'players': 11},
#  {'date': '2023-04-15T09:40:00.000Z',
#   'format': None,
#   'game': 'PTCG',
#   'id': '643a6fb40ed4a405d8bd59bb',
#   'name': 'Euic 2007 tournament ',
#   'players': 9},
#  {'date': '2023-04-15T02:05:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '642cbf4caf9fbd0613b1e79d',
#   'name': 'TOURNAMENT OF DOOM! Goes to Australia!',
#   'players': 70},
#  {'date': '2023-04-15T00:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '6434b6d10ed4a405d8bd4123',
#   'name': 'Hoarders Circuit Series #19 Post Rotation',
#   'players': 101},
#  {'date': '2023-04-14T21:20:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '643475240ed4a405d8bd3e8f',
#   'name': 'Just Chilling Games #3 Free',
#   'players': 17},
#  {'date': '2023-04-14T20:30:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '642f8077af9fbd0613b1fcd7',
#   'name': 'Pokevice League - Pokémon TCG #2',
#   'players': 22},
#  {'date': '2023-04-14T12:30:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '643036250ed4a405d8bd1cc7',
#   'name': 'The Discard Pile Weekly #8 Special RULES!!!!',
#   'players': 18},
#  {'date': '2023-04-14T00:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '6434b0230ed4a405d8bd40f1',
#   'name': 'Hoarders Casual #28 Post Rotation',
#   'players': 57},
#  {'date': '2023-04-13T23:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '63fe75372fb42a11441fc032',
#   'name': 'Free Entry | $130 Store Credit | Qualifier #7',
#   'players': 175},
#  {'date': '2023-04-13T23:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '64384c040ed4a405d8bd504b',
#   'name': 'PS LEAGUE ETAPA #64',
#   'players': 12},
#  {'date': '2023-04-13T22:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '642f6949af9fbd0613b1fb51',
#   'name': 'PLive League BR #2 - Swiss',
#   'players': 4},
#  {'date': '2023-04-13T12:55:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '643347490ed4a405d8bd38a4',
#   'name': 'EUIC Last Chance Testing',
#   'players': 11},
#  {'date': '2023-04-13T00:05:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '641b2d5125171155a799c84a',
#   'name': 'Full Heal S2 #2 (50 Codes, FREE ENTRY!)',
#   'players': 158},
#  {'date': '2023-04-12T23:25:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '64362a5a0ed4a405d8bd46ed',
#   'name': 'FTG Wednesday Weekly 75',
#   'players': 24},
#  {'date': '2023-04-12T23:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '64341c820ed4a405d8bd3c01',
#   'name': 'Poke Liga Online 12/04',
#   'players': 11},
#  {'date': '2023-04-12T19:00:00.000Z',
#   'format': 'GLC',
#   'game': 'PTCG',
#   'id': '642e9ff8af9fbd0613b1f43a',
#   'name': 'CBW GLC Webcam #2',
#   'players': 7},
#  {'date': '2023-04-12T13:30:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '643209440ed4a405d8bd2f06',
#   'name': 'MorningTCG Weekly #1 |PTCGL| 36 SV Codes|',
#   'players': 64},
#  {'date': '2023-04-12T12:30:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '642d9a2daf9fbd0613b1ee46',
#   'name': 'The Discard Pile Live Standard Weekly #7',
#   'players': 79},
#  {'date': '2023-04-12T00:30:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '642c3f4aaf9fbd0613b1dd25',
#   'name': 'Hoarders Casual #27 Post Rotation',
#   'players': 147},
#  {'date': '2023-04-11T00:00:00.000Z',
#   'format': 'RMEP',
#   'game': 'PTCG',
#   'id': '643470740ed4a405d8bd3e6b',
#   'name': 'Underground special',
#   'players': 77},
#  {'date': '2023-04-10T22:05:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '642b8877af9fbd0613b1db2e',
#   'name': "Sunny's Weekly #98",
#   'players': 64},
#  {'date': '2023-04-10T22:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '6433668a0ed4a405d8bd39e4',
#   'name': 'FalaMeowth! "5/0 Hero" #06',
#   'players': 32},
#  {'date': '2023-04-10T18:51:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '64345a910ed4a405d8bd3d90',
#   'name': 'S&V Monday! Friendly T ',
#   'players': 10},
#  {'date': '2023-04-10T18:00:00.000Z',
#   'format': 'RMEP',
#   'game': 'PTCG',
#   'id': '6432b8440ed4a405d8bd32b7',
#   'name': 'Pumpka Weekly post rotation tournament',
#   'players': 64},
#  {'date': '2023-04-10T16:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '638c60d873053a08b70b666f',
#   'name': 'Testing with close deck list',
#   'players': 19},
#  {'date': '2023-04-10T11:30:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '642af3a7af9fbd0613b1d502',
#   'name': 'Monday Morning Matches #10',
#   'players': 46},
#  {'date': '2023-04-09T23:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '642e0ff6af9fbd0613b1f22a',
#   'name': "Shamrock's: We Liming #003",
#   'players': 112},
#  {'date': '2023-04-09T19:00:00.000Z',
#   'format': '',
#   'game': 'PTCG',
#   'id': '6431b2b40ed4a405d8bd2b3a',
#   'name': 'Just Chilling Games #2 Post-Rotation Free',
#   'players': 66},
#  {'date': '2023-04-09T17:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '642c8536af9fbd0613b1e275',
#   'name': 'Trainer Academy|SV POST ROTATION|80 CODES|',
#   'players': 129},
#  {'date': '2023-04-09T03:40:00.000Z',
#   'format': 'EXPANDED',
#   'game': 'PTCG',
#   'id': '64285442af9fbd0613b1c9f7',
#   'name': 'Webcam Series Kickoff',
#   'players': 16},
#  {'date': '2023-04-09T00:30:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '642c7981af9fbd0613b1e1cc',
#   'name': 'Hoarders Circuit Series #18 BST-SV',
#   'players': 135},
#  {'date': '2023-04-08T23:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '641c386225171155a799cc50',
#   'name': 'Poke Liga Online 08/04',
#   'players': 4},
#  {'date': '2023-04-08T18:00:00.000Z',
#   'format': 'CUSTOM',
#   'game': 'PTCG',
#   'id': '641f304925171155a799da33',
#   'name': 'Card Art SV Legal 1K',
#   'players': 47},
#  {'date': '2023-04-08T18:00:00.000Z',
#   'format': 'EXPANDED',
#   'game': 'PTCG',
#   'id': '643193510ed4a405d8bd2947',
#   'name': 'Safari Zone - Standard Tournament - 4/8/23',
#   'players': 36},
#  {'date': '2023-04-08T18:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '643064940ed4a405d8bd1ee9',
#   'name': '2023 GU Saturday Tournament #13 (Post-Rotation)',
#   'players': 19},
#  {'date': '2023-04-08T17:00:00.000Z',
#   'format': 'RMEP',
#   'game': 'PTCG',
#   'id': '63b1c1e4fa281305be50dfb5',
#   'name': 'LuckySquad Grinder #7 | Sponsored by Pokemons.dk',
#   'players': 86},
#  {'date': '2023-04-08T15:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '641f7f0f25171155a799dc56',
#   'name': 'PKMN Live Scarlet&Violet (Free Entry)',
#   'players': 10},
#  {'date': '2023-04-08T13:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '642c5651af9fbd0613b1deeb',
#   'name': 'Semanal UG - Sábado',
#   'players': 12},
#  {'date': '2023-04-08T13:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '642ffb500ed4a405d8bd1bbe',
#   'name': "Dave's Easter Tournament ",
#   'players': 60},
#  {'date': '2023-04-08T10:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '63d5a28031c92b05d27e5e8b',
#   'name': 'Rule Zero Win a Box Scarlet & Violet',
#   'players': 29},
#  {'date': '2023-04-08T02:35:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '642472df25171155a799eef8',
#   'name': 'TOURNAMENT OF DOOM! Goes to Europe!',
#   'players': 155},
#  {'date': '2023-04-08T00:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '642c7917af9fbd0613b1e1cb',
#   'name': 'Hoarders Circuit Series #17 BST-SV ',
#   'players': 53},
#  {'date': '2023-04-07T23:30:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '642a15bfaf9fbd0613b1d2c5',
#   'name': 'Just Chilling #1 Post-Rotation Free',
#   'players': 45},
#  {'date': '2023-04-07T23:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '642b5e1daf9fbd0613b1d974',
#   'name': 'seniors ptcgL tournament 2',
#   'players': 12},
#  {'date': '2023-04-07T22:45:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '6421cb1525171155a799e229',
#   'name': 'Lax-Station Post-Rotation Webcam',
#   'players': 22},
#  {'date': '2023-04-07T20:00:00.000Z',
#   'format': 'RMEP',
#   'game': 'PTCG',
#   'id': '642db211af9fbd0613b1eece',
#   'name': 'Pumpka Weekly post rotation tournament',
#   'players': 64},
#  {'date': '2023-04-07T20:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '640fd45a25171155a799901b',
#   'name': 'Pokevice League - Pokémon TCG #1',
#   'players': 46},
#  {'date': '2023-04-07T18:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '64253a7d25171155a799f2bb',
#   'name': 'Black Tower Pokemon Weekly #31',
#   'players': 21},
#  {'date': '2023-04-07T16:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '642db550af9fbd0613b1eef3',
#   'name': 'Pokemon tcg suomi PTCGL tournament! 30 CODES!',
#   'players': 112},
#  {'date': '2023-04-07T12:30:00.000Z',
#   'format': 'CUSTOM',
#   'game': 'PTCG',
#   'id': '6426f83825171155a799fa1d',
#   'name': 'The Discard Pile Live Weekly #6',
#   'players': 28},
#  {'date': '2023-04-07T00:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '642c7806af9fbd0613b1e1c7',
#   'name': 'Hoarders Casual #26 BST-SV',
#   'players': 38},
#  {'date': '2023-04-06T23:15:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '642b604faf9fbd0613b1d987',
#   'name': 'Copa Quaquaval PTCGL #03',
#   'players': 12},
#  {'date': '2023-04-06T23:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '64260ebb25171155a799f54d',
#   'name': 'Free entry | $500 Store Credit |Qualifier #6',
#   'players': 284},
#  {'date': '2023-04-06T23:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '642f3b54af9fbd0613b1f75b',
#   'name': 'PS LEAGUE ETAPA #63',
#   'players': 15},
#  {'date': '2023-04-06T23:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '642dedd9af9fbd0613b1f01f',
#   'name': 'Gaming Universe Thursday Tournament 04/06',
#   'players': 18},
#  {'date': '2023-04-06T22:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '6427ad3825171155a799fefa',
#   'name': 'PLive League BR #1 - Swiss',
#   'players': 11},
#  {'date': '2023-04-06T18:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '642e82b6af9fbd0613b1f405',
#   'name': 'Hidden Gem Weeknight League',
#   'players': 8},
#  {'date': '2023-04-06T18:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '642abd3eaf9fbd0613b1d419',
#   'name': 'S&V Thursday!  ',
#   'players': 12},
#  {'date': '2023-04-06T18:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '6428004caf9fbd0613b1c8fd',
#   'name': 'Rule Zero’s SVI - League #1',
#   'players': 41},
#  {'date': '2023-04-06T16:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '642e47b9af9fbd0613b1f3b9',
#   'name': 'Grinding',
#   'players': 29},
#  {'date': '2023-04-06T00:00:00.000Z',
#   'format': 'GLC',
#   'game': 'PTCG',
#   'id': '641b1d0025171155a799c826',
#   'name': 'CBW GLC Webcam #1',
#   'players': 7},
#  {'date': '2023-04-05T23:30:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '642c4849af9fbd0613b1dd7c',
#   'name': 'FTG Wednesday Weekly 74',
#   'players': 34},
#  {'date': '2023-04-05T23:00:00.000Z',
#   'format': 'CUSTOM',
#   'game': 'PTCG',
#   'id': '642b7445af9fbd0613b1daa3',
#   'name': 'Junior Free-4-All',
#   'players': 15},
#  {'date': '2023-04-05T23:00:00.000Z',
#   'format': 'RMEP',
#   'game': 'PTCG',
#   'id': '642cdfaaaf9fbd0613b1eb2b',
#   'name': 'underground special',
#   'players': 90},
#  {'date': '2023-04-05T12:30:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '6422440925171155a799e515',
#   'name': 'The Discard Pile Live Standard Weekly #5',
#   'players': 70},
#  {'date': '2023-04-05T00:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '642c3dcaaf9fbd0613b1dd1d',
#   'name': 'Hoarders Casual #25 BST-SV',
#   'players': 34},
#  {'date': '2023-04-04T23:37:00.000Z',
#   'format': 'CUSTOM',
#   'game': 'PTCG',
#   'id': '642c440faf9fbd0613b1dd45',
#   'name': "Liga Jornada na Player's Stop #13",
#   'players': 4},
#  {'date': '2023-04-04T23:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '64066d6624ea2b561a98789f',
#   'name': 'Late Night #88 on PTCG Live | SV Legal ',
#   'players': 453},
#  {'date': '2023-04-04T16:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '64066c5024ea2b561a987898',
#   'name': 'Late Night #87 on PTCG Live | SV Legal',
#   'players': 284},
#  {'date': '2023-04-04T00:05:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '642b56d4af9fbd0613b1d91c',
#   'name': 'seniors ptcgL tournament',
#   'players': 8},
#  {'date': '2023-04-04T00:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '642adadaaf9fbd0613b1d4a7',
#   'name': 'Hoarders Casual #24 BST-SV',
#   'players': 86},
#  {'date': '2023-04-03T22:05:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '64224fa425171155a799e539',
#   'name': "Sunny's Weekly #97",
#   'players': 64},
#  {'date': '2023-04-03T22:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '641a2c3225171155a799c35c',
#   'name': 'Italian League Pokemon season #1',
#   'players': 20},
#  {'date': '2023-04-03T22:00:00.000Z',
#   'format': 'CUSTOM',
#   'game': 'PTCG',
#   'id': '642b4132af9fbd0613b1d7e4',
#   'name': 'Next level Weekly ',
#   'players': 14},
#  {'date': '2023-04-03T22:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '642a0654af9fbd0613b1d269',
#   'name': 'FalaMeowth! "5/0 Hero" #05',
#   'players': 27},
#  {'date': '2023-04-03T18:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '64219c9625171155a799e191',
#   'name': 'Pumpka+ADL FREE 1K TCG Code EUIC format',
#   'players': 179},
#  {'date': '2023-04-03T11:30:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '6422361e25171155a799e4e6',
#   'name': 'Monday Morning Matches #9',
#   'players': 32},
#  {'date': '2023-04-03T00:00:00.000Z',
#   'format': 'CUSTOM',
#   'game': 'PTCG',
#   'id': '642a075daf9fbd0613b1d26d',
#   'name': 'Junior Free-4-All',
#   'players': 8},
#  {'date': '2023-04-02T17:30:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '6429b864af9fbd0613b1cf93',
#   'name': 'Pré-Release Violeta e Escarte',
#   'players': 12},
#  {'date': '2023-04-02T17:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '642421a825171155a799ee34',
#   'name': 'Trainer Academy|PTCG Live|SV POST ROTATION|EUIC|',
#   'players': 105},
#  {'date': '2023-04-02T15:00:00.000Z',
#   'format': 'BASENEO',
#   'game': 'PTCG',
#   'id': '641c6af425171155a799cca9',
#   'name': '\U0001f7e4 League Challenge 1 (Abril 2023 - Batipancho)',
#   'players': 22},
#  {'date': '2023-04-02T08:30:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '641f933425171155a799dc84',
#   'name': 'Pokemon Scarlet & Violet vårturnering',
#   'players': 23},
#  {'date': '2023-04-02T08:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '6410f07525171155a7999490',
#   'name': 'Nightspear89 & GabianoGames 2.0',
#   'players': 50},
#  {'date': '2023-04-01T23:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '6428478caf9fbd0613b1c9a0',
#   'name': 'Poke Liga Online 01/04',
#   'players': 9},
#  {'date': '2023-04-01T19:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '6428731eaf9fbd0613b1cab2',
#   'name': 'Pre Release - Cardshall ',
#   'players': 23},
#  {'date': '2023-04-01T18:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '6427574d25171155a799fc09',
#   'name': '2023 GU Saturday Tournament #12 (Post-Rotation)',
#   'players': 21},
#  {'date': '2023-04-01T15:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '64273a6925171155a799fb48',
#   'name': 'Pokemon tcg suomi saturday PTCGL test event!',
#   'players': 42},
#  {'date': '2023-04-01T03:55:00.000Z',
#   'format': 'CUSTOM',
#   'game': 'PTCG',
#   'id': '6424687125171155a799eeb9',
#   'name': 'SMG Webcam TCG Tournament ',
#   'players': 4},
#  {'date': '2023-04-01T02:40:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '6405245824ea2b561a98749c',
#   'name': 'TOURNAMENT OF DOOM! Dawn of PTCGL',
#   'players': 119},
#  {'date': '2023-04-01T01:10:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '642765bb25171155a799fc51',
#   'name': 'TanoCup #27',
#   'players': 18},
#  {'date': '2023-04-01T00:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '6427236c25171155a799facd',
#   'name': 'Hoarders Circuit Series #16 BST-SV Post Rotation',
#   'players': 36},
#  {'date': '2023-03-31T18:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '641977b425171155a799bf77',
#   'name': 'Black Tower Pokemon Weekly #30 (EUIC Format)',
#   'players': 16},
#  {'date': '2023-03-31T12:30:00.000Z',
#   'format': 'CUSTOM',
#   'game': 'PTCG',
#   'id': '641dd08025171155a799d2d7',
#   'name': 'The Discard Pile Live Weekly #4',
#   'players': 17},
#  {'date': '2023-03-31T00:00:00.000Z',
#   'format': 'CUSTOM',
#   'game': 'PTCG',
#   'id': '6425896a25171155a799f33a',
#   'name': 'Hoarders Casual #23 Post Rotation BST-SV1',
#   'players': 30},
#  {'date': '2023-03-30T23:20:00.000Z',
#   'format': '',
#   'game': 'PTCG',
#   'id': '6426174225171155a799f60a',
#   'name': 'Teste',
#   'players': 8},
#  {'date': '2023-03-30T23:15:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '641da55225171155a799d259',
#   'name': 'Copa Quaquaval PTCGL #02 - ALREADY POST ROTATION',
#   'players': 14},
#  {'date': '2023-03-30T23:00:00.000Z',
#   'format': 'RMEP',
#   'game': 'PTCG',
#   'id': '63fe714c2fb42a11441fc021',
#   'name': 'Free entry | $500 Store Credit | POST ROTATION',
#   'players': 184},
#  {'date': '2023-03-30T23:00:00.000Z',
#   'format': 'RMEP',
#   'game': 'PTCG',
#   'id': '6413c19125171155a799a32a',
#   'name': 'Webcam Wars - Open #4 - Post-Rotation',
#   'players': 11},
#  {'date': '2023-03-30T23:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '642478ff25171155a799ef1f',
#   'name': 'PS LEAGUE ETAPA #62',
#   'players': 20},
#  {'date': '2023-03-30T22:40:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '6421813825171155a799e156',
#   'name': 'Semanal Quinta na Vault!',
#   'players': 9},
#  {'date': '2023-03-30T18:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '6422bae225171155a799e5aa',
#   'name': 'Hidden Gem Weeknight League',
#   'players': 8},
#  {'date': '2023-03-30T18:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '64220f4925171155a799e384',
#   'name': 'Rule Zero’s BST > ScVi Test #5',
#   'players': 40},
#  {'date': '2023-03-30T00:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '6423ca7725171155a799ede9',
#   'name': ' Hoarders Store Credit #2',
#   'players': 5},
#  {'date': '2023-03-29T23:25:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '6420e81e25171155a799e0b7',
#   'name': 'FTG Wednesday Weekly 73 (POST ROTATION ScVi LEGAL)',
#   'players': 32},
#  {'date': '2023-03-29T00:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '64234c6d25171155a799e958',
#   'name': 'Hoarders Circuit Series #15',
#   'players': 39},
#  {'date': '2023-03-28T23:36:00.000Z',
#   'format': 'CUSTOM',
#   'game': 'PTCG',
#   'id': '6422dc5925171155a799e5db',
#   'name': "Liga Jornada na Player's Stop #12",
#   'players': 4},
#  {'date': '2023-03-28T23:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '640668f724ea2b561a987866',
#   'name': 'Late Night #86 | Last NA LN on PTCGO',
#   'players': 142},
#  {'date': '2023-03-28T16:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '6406681424ea2b561a987856',
#   'name': 'Late Night #85 | Last EU LN on PTCGO',
#   'players': 90},
#  {'date': '2023-03-28T00:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '6422210325171155a799e3fd',
#   'name': 'Hoarders Casual #22',
#   'players': 18},
#  {'date': '2023-03-27T22:05:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '641912c425171155a799bef5',
#   'name': "Sunny's Weekly #96 Welcome to PTCGL",
#   'players': 44},
#  {'date': '2023-03-27T22:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '641d6b2125171155a799d1ca',
#   'name': 'FalaMeowth! "5/0 Hero" #04',
#   'players': 12},
#  {'date': '2023-03-27T18:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '64202a1125171155a799ddac',
#   'name': 'FIRST PTCGLive Pumpka Weekly!',
#   'players': 45},
#  {'date': '2023-03-27T11:30:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '641872a925171155a799bb0a',
#   'name': 'Monday Morning Matches #8 LIVE',
#   'players': 32},
#  {'date': '2023-03-26T22:15:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '640492c324ea2b561a98702a',
#   'name': 'Peladão Showdown LIVE | EXPLORER Format Vol.2',
#   'players': 8},
#  {'date': '2023-03-26T18:00:00.000Z',
#   'format': 'SUMLOT',
#   'game': 'PTCG',
#   'id': '641fef2f25171155a799dd54',
#   'name': 'Goodbye PTCGO: SUM-LOT format (50 CRZ codes)',
#   'players': 8},
#  {'date': '2023-03-25T23:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '64166b9125171155a799b3ae',
#   'name': 'Poke Liga Online 25/03',
#   'players': 8},
#  {'date': '2023-03-25T22:00:00.000Z',
#   'format': 'EXPANDED',
#   'game': 'PTCG',
#   'id': '640d386521433a05cd053858',
#   'name': 'PTCGO Crown Zenith (Free Entry)(Codes for All)',
#   'players': 11},
#  {'date': '2023-03-25T21:30:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '640147b72fb42a11441fd4b0',
#   'name': 'Kaeru Games -  TCG Snorlax Edition',
#   'players': 6},
#  {'date': '2023-03-25T19:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '641a07ed25171155a799c264',
#   'name': "MrDog's Standard Tournament",
#   'players': 7},
#  {'date': '2023-03-25T17:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '6402641424ea2b561a98617d',
#   'name': 'Pokemon Tourney at the Union Marketplace!',
#   'players': 29},
#  {'date': '2023-03-25T13:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '6413d7cc25171155a799a3da',
#   'name': 'Poké Sábado Championships 25/03',
#   'players': 10},
#  {'date': '2023-03-25T03:59:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '6412636a25171155a7999d54',
#   'name': 'SMG Webcam TCG Tournament ',
#   'players': 3},
#  {'date': '2023-03-25T02:35:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '640523bf24ea2b561a98749b',
#   'name': 'SUPER TOURNAMENT OF DOOM! THE END OF PTCGO',
#   'players': 46},
#  {'date': '2023-03-25T00:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '641de8ab25171155a799d32c',
#   'name': 'Hoarders Circuit Series #14',
#   'players': 22},
#  {'date': '2023-03-24T23:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '640df33f21433a05cd053a08',
#   'name': "SHAMROCK'S MARCH 2023 CHAMPIONSHIP",
#   'players': 50},
#  {'date': '2023-03-24T20:05:00.000Z',
#   'format': '2010',
#   'game': 'PTCG',
#   'id': '641cbfb525171155a799ce10',
#   'name': '2010 Format - Charlotte Regionals',
#   'players': 25},
#  {'date': '2023-03-24T20:00:00.000Z',
#   'format': 'GLC',
#   'game': 'PTCG',
#   'id': '641b632825171155a799c954',
#   'name': 'FINAL Gym Leader Challenge :(',
#   'players': 22},
#  {'date': '2023-03-24T19:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '6402826324ea2b561a98627a',
#   'name': 'Black Tower Pokemon weekly #29 (EUIC Format)',
#   'players': 20},
#  {'date': '2023-03-24T18:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '641de1e425171155a799d30c',
#   'name': '2023 GU Saturday Tournament #11 (Post-Rotation)',
#   'players': 13},
#  {'date': '2023-03-24T12:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '64149fb225171155a799a56d',
#   'name': 'The Discard Pile LIVE Weekly #3',
#   'players': 11},
#  {'date': '2023-03-24T00:00:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '641c9a8e25171155a799cd02',
#   'name': 'Hoarders Casual #21',
#   'players': 18},
#  {'date': '2023-03-23T23:15:00.000Z',
#   'format': 'STANDARD',
#   'game': 'PTCG',
#   'id': '6414916d25171155a799a529',
#   'name': 'Copa Quaquaval PTCGL #01',
#   'players': 13}]
